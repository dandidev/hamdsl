// %%
import io.github.dandidev.hamdsl.dsl.si.A
import io.github.dandidev.hamdsl.dsl.si.Ohm
import io.github.dandidev.hamdsl.dsl.si.V
import io.github.dandidev.hamdsl.dsl.si.kOhm
import io.github.dandidev.hamdsl.format.UnitFormatter
import io.github.dandidev.hamdsl.units.si.div
import io.github.dandidev.hamdsl.units.si.times

val voltage = 5.A * 3.Ohm
val current = 5.V / 10.kOhm
val resistance = 2.V / 4.A

"""
Voltage            : $voltage
Current            : $current
Resistance         : $resistance

Voltage auto formatted     : ${UnitFormatter.format(voltage)}
Current auto formatted     : ${UnitFormatter.format(current)}
Resistance auto formatted  : ${UnitFormatter.format(resistance)}
""".trimIndent()
// Out:
// Voltage            : Volt(value=15.0)
// Current            : Ampere(value=5.0E-4)
// Resistance         : Ohm(value=0.5)
//
// Voltage auto formatted     : 15.0000 V
// Current auto formatted     : 500.0000 µA
// Resistance auto formatted  : 500.0000 mΩ
