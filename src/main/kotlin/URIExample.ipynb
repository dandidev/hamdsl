// %%
import io.github.dandidev.hamdsl.dsl.A
import io.github.dandidev.hamdsl.dsl.Ohm
import io.github.dandidev.hamdsl.dsl.V
import io.github.dandidev.hamdsl.units.div
import io.github.dandidev.hamdsl.units.times
import io.github.dandidev.hamdsl.units.toMicroVolt
import io.github.dandidev.hamdsl.units.toMilliVolt

val voltage = 2.A * 3.Ohm
val current = 5.V / 4.Ohm

"""
Voltage               : $voltage
Current               : $current
""".trimIndent()
// Out:
// Voltage               : 6.0000 V
// Current               : 1.2500 A
