// %%
import io.github.dandidev.hamdsl.dsl.A
import io.github.dandidev.hamdsl.dsl.Ohm
import io.github.dandidev.hamdsl.dsl.V
import io.github.dandidev.hamdsl.dsl.kOhm
import io.github.dandidev.hamdsl.units.Volt
import io.github.dandidev.hamdsl.units.div
import io.github.dandidev.hamdsl.units.times

val voltage = 5.A * 3.Ohm
val current = 5.V / 10.kOhm
val resistance = 2.V / 4.A

"""
Voltage            : $voltage
Current            : $current
Resistance         : $resistance
""".trimIndent()
// Out:
// Voltage            : 15,0000 V
// Current            : 0,0005 A
// Resistance         : 0,5000 Ω
